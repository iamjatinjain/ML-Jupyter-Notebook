# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#without the semi colon

plt.plot()
# Out:
# []

# %%
plt.plot(); #with the semi colon

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4])

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x,y);

# %%
plt.plot()
# Out:
# []

# %%
# Creating plot using different methods

fig = plt.figure() #creates a figure
ax = fig.add_subplot() #adds axis
plt.plot()
# Out:
# []

# %%
# method 2

fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x,y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y); #adding some data

# %%
fig, ax = plt.subplots()
ax.plot(x,[50, 100, 200, 250]);

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib workflow

# %%
#0 import matplotlib and get ready to plot in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare Data
x=[1, 2, 3, 4]
y=[11, 22, 33, 44]

#2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10))

#3. Plot Data
ax.plot(x,y)

#4. Customize plot
ax.set(title = "Simple Plot",
      xlabel = "x-axis",
      ylabel = "y-axis")

#5. Save and show (save the whole figure)
fig.savefig("images/sample-plot.png")

# %%
#0 import matplotlib and get ready to plot in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare Data
x=[1, 2, 3, 4]
y=[11, 22, 33, 44]

#2. Setup plot
fig, ax = plt.subplots(figsize=(5, 10))

#3. Plot Data
ax.plot(x,y)

#4. Customize plot
ax.set(title = "Simple Plot",
      xlabel = "x-axis",
      ylabel = "y-axis")

#5. Save and show (save the whole figure)
fig.savefig("images/sample-plot2.png")

# %% [markdown]
# ## Making figures with numpy array

# %% [markdown]
# ### Line Plot

# %%
import numpy as np

# %%
#create some Data

x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# PLot the data and create the line plot

fig, ax = plt.subplots()
ax.plot(x, x**2);

# %% [markdown]
# ### Scatter Plot

# %%
# Using the same data to plot the Scatter

fig, ax = plt.subplots()
ax.scatter(x, x**2);

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another Scatter Plot

fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from Dictionary

nut_butter_prices = {"Almond Butter": 10,
                     "Peanut Butter": 8,
                     "Cashew Butter": 12}

fig, ax = plt.subplots()
ax.scatter(nut_butter_prices.keys(), nut_butter_prices.values())

# %% [markdown]
# ### Bar Plot

# %%
nut_butter_prices = {"Almond Butter": 10,
                     "Peanut Butter": 8,
                     "Cashew Butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
# Out:
# <BarContainer object of 3 artists>

# %%
nut_butter_prices = {"Almond Butter": 10,
                     "Peanut Butter": 8,
                     "Cashew Butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)")
# Out:
# [Text(0, 0.5, 'Price ($)'), Text(0.5, 1.0, "Dan's Nut Butter Store")]

# %%
nut_butter_prices = {"Almond Butter": 10,
                     "Peanut Butter": 8,
                     "Cashew Butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)"); # ; removes the line

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
#
#        -8.61285794e-02,  1.62900885e+00, -4.38285922e-01,  6.62401754e-01,
#         5.86477658e-01, -1.47851540e+00, -1.60774013e+00, -1.85746171e+00,
#        -6.23395460e-01,  1.57117225e+00,  1.60944977e-01, -1.02473791e+00,
#         7.13561068e-01,  7.43472264e-01,  5.47733586e-01,  3.38470480e-01,
#        -7.10909134e-01, -1.64843053e+00,  3.80682235e-02, -2.11598656e-02,
#         1.52436318e+00,  9.24220551e-01,  4.37028837e-01,  1.87601742e+00,
#        -1.45928931e+00, -5.25084655e-01, -3.05819050e-01,  1.94821957e+00,
#         5.71616804e-01, -1.12028546e+00, -7.65478089e-01,  8.49727970e-01,
#         9.00593835e-01, -4.47103866e-01, -5.61412141e-01, -1.03774519e+00,
#        -9.78057444e-02,  4.03587959e-01, -6.77438081e-01, -4.95374349e-01,
#         3.41223503e-01,  2.45154519e+00,  8.07908848e-01, -1.01340013e-01,
#         1.65171752e-01, -8.32611878e-01, -1.64173042e+00,  1.58258306e+00,
#        -5.23283161e-01,  6.21596206e-01,  5.69882263e-01,  1.22232432e+00,
#        -1.82895192e+00, -2.19925806e+00, -1.43009045e+00,  3.24370113e-01])

# %%
x = np.random.randn(1000) #normal distribution
fig, ax = plt.subplots()
ax.hist(x);

# %%
x = np.random.random(1000) #random distribution
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Subplots

# %% [markdown]
# ### Two options on Subplots

# %%
## Subplot option 1

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))
ax1.plot(x, x/2);

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))
ax1.plot(x, x/2);
ax2.scatter(np.random.random(20), np.random.random(20));

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))
ax1.plot(x, x/2);
ax2.scatter(np.random.random(20), np.random.random(20))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
# Out:
# <BarContainer object of 3 artists>

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))

# Plot to each different axis

ax1.plot(x, x/2);
ax2.scatter(np.random.random(20), np.random.random(20))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(100));

# %%
# Subplot Option 2

fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))
ax[0, 0].plot(x, x/2);

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (10,5))

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (10,4))

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 3, figsize = (10,5))

# %%
# Subplot Option 2

fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))

#Plot to each different index

ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(20), np.random.random(20))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(100));

# %% [markdown]
# ## Plotting from pandas DataFrame

# %%
import pandas as pd

# %%
# Make a Data Frame

car_sales = pd.read_csv("car-data.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Plot using Series

# %%
ts = pd.Series(np.random.randn(1000), 
              index = pd.date_range("07/01/2020", periods = 1000))
ts
# Out:
# 2020-07-01   -0.748592
# 2020-07-02    0.873192
# 2020-07-03   -1.076813
# 2020-07-04    0.219764
# 2020-07-05    1.880954
#                 ...
# 2023-03-23    0.893870
# 2023-03-24    0.478178
# 2023-03-25   -0.269264
# 2023-03-26    0.489487
# 2023-03-27   -0.685420
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts
# Out:
# 2020-07-01    -0.748592
# 2020-07-02     0.124600
# 2020-07-03    -0.952214
# 2020-07-04    -0.732450
# 2020-07-05     1.148504
#                 ...
# 2023-03-23    18.960504
# 2023-03-24    19.438682
# 2023-03-25    19.169418
# 2023-03-26    19.658906
# 2023-03-27    18.973486
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
ts = pd.Series(np.random.randn(1000), 
              index = pd.date_range("07/01/2020", periods = 1000))
ts.cumsum().plot()

# %%
ts = pd.Series(np.random.randn(1000), 
              index = pd.date_range("07/01/2020", periods = 1000))
ts.cumsum()
ts.plot();

# %% [markdown]
# ## Plot using Data Frame

# %%
car_sales = pd.read_csv("car-data.csv")

# %%
# turning Price column in Integer format and remove the symbols

car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# Remove last two zeroes

car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("07/01/2020", periods = len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-07-01
# 1   Honda    Red          87899      4   5000 2020-07-02
# 2  Toyota   Blue          32549      3   7000 2020-07-03
# 3     BMW  Black          11179      5  22000 2020-07-04
# 4  Nissan  White         213095      4   3500 2020-07-05
# 5  Toyota  Green          99213      4   4500 2020-07-06
# 6   Honda   Blue          45698      4   7500 2020-07-07
# 7   Honda   Blue          54738      4   7000 2020-07-08
# 8  Toyota  White          60000      4   6250 2020-07-09
# 9  Nissan  White          31600      4   9700 2020-07-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  \
# 0  Toyota  White         150043      4   4000 2020-07-01
# 1   Honda    Red          87899      4   5000 2020-07-02
# 2  Toyota   Blue          32549      3   7000 2020-07-03
# 3     BMW  Black          11179      5  22000 2020-07-04
# 4  Nissan  White         213095      4   3500 2020-07-05
# 5  Toyota  Green          99213      4   4500 2020-07-06
# 6   Honda   Blue          45698      4   7500 2020-07-07
# 7   Honda   Blue          54738      4   7000 2020-07-08
# 8  Toyota  White          60000      4   6250 2020-07-09
# 9  Nissan  White          31600      4   9700 2020-07-10
#
#                                  Total Sales
# 0                                       4000
# 1                                   40005000
# 2                               400050007000
# 3                          40005000700022000
# 4                      400050007000220003500
# 5                  4000500070002200035004500
# 6              40005000700022000350045007500
# 7          400050007000220003500450075007000
# 8      4000500070002200035004500750070006250
# 9  40005000700022000350045007500700062509700

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-07-01         4000
# 1   Honda    Red          87899      4   5000 2020-07-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-07-03        16000
# 3     BMW  Black          11179      5  22000 2020-07-04        38000
# 4  Nissan  White         213095      4   3500 2020-07-05        41500
# 5  Toyota  Green          99213      4   4500 2020-07-06        46000
# 6   Honda   Blue          45698      4   7500 2020-07-07        53500
# 7   Honda   Blue          54738      4   7000 2020-07-08        60500
# 8  Toyota  White          60000      4   6250 2020-07-09        66750
# 9  Nissan  White          31600      4   9700 2020-07-10        76450

# %%
# Plotting Total Sales

car_sales.plot(x = "Sale Date", y = "Total Sales");

# %% [markdown]
# ## To plot scatter plot

# %%
# Convert Price to int
car_sales["Price"] = car_sales["Price"].astype(int)

# Using scatter plot
car_sales.plot(x="Odometer (KM)", y="Price", kind='scatter');

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-07-01         4000
# 1   Honda    Red          87899      4   5000 2020-07-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-07-03        16000
# 3     BMW  Black          11179      5  22000 2020-07-04        38000
# 4  Nissan  White         213095      4   3500 2020-07-05        41500
# 5  Toyota  Green          99213      4   4500 2020-07-06        46000
# 6   Honda   Blue          45698      4   7500 2020-07-07        53500
# 7   Honda   Blue          54738      4   7000 2020-07-08        60500
# 8  Toyota  White          60000      4   6250 2020-07-09        66750
# 9  Nissan  White          31600      4   9700 2020-07-10        76450

# %% [markdown]
# ## Bar Graph

# %%
x = np.random.rand(10, 4)
x
# Out:
# array([[0.46920204, 0.47932025, 0.08440514, 0.7987435 ],
#        [0.74340489, 0.54762508, 0.34203166, 0.4586653 ],
#        [0.45148117, 0.9605627 , 0.92112002, 0.96626479],
#        [0.74294814, 0.38867319, 0.67478362, 0.47161369],
#        [0.30000006, 0.40031175, 0.39194527, 0.34022019],
#        [0.41947842, 0.51810204, 0.10470462, 0.64778814],
#        [0.11118475, 0.17761406, 0.00999014, 0.47271385],
#        [0.13930206, 0.13725257, 0.98550057, 0.45881059],
#        [0.0668361 , 0.71418768, 0.94202928, 0.20991906],
#        [0.06680911, 0.95556427, 0.2521995 , 0.39574425]])

# %%
# Turn it into a dataframe

df = pd.DataFrame(x, columns = ['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.469202  0.479320  0.084405  0.798743
# 1  0.743405  0.547625  0.342032  0.458665
# 2  0.451481  0.960563  0.921120  0.966265
# 3  0.742948  0.388673  0.674784  0.471614
# 4  0.300000  0.400312  0.391945  0.340220
# 5  0.419478  0.518102  0.104705  0.647788
# 6  0.111185  0.177614  0.009990  0.472714
# 7  0.139302  0.137253  0.985501  0.458811
# 8  0.066836  0.714188  0.942029  0.209919
# 9  0.066809  0.955564  0.252200  0.395744

# %%
df.plot.bar();

# %%
df.plot(kind = "bar")

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
# Histograms again

car_sales["Odometer (KM)"].plot.hist()

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
# Default number of bins is 10 
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
car_sales["Odometer (KM)"].plot.hist(bins=25);

# %%
car_sales["Odometer (KM)"].plot.hist(bins=5);

# %%
car_sales["Odometer (KM)"].plot.hist(bins= 10);

# %%
# Using another dataset
import pandas as pd
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist();

# %%
heart_disease["age"].plot.hist(bins=30);

# %%
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist()

# %%
heart_disease.plot.hist(subplots = True);

# %%
heart_disease.plot.hist(figsize = (10,30), subplots = True);

# %%
# when plotting something advanced - Use OO method

heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot method

over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
len(over_50)
# Out:
# 208

# %%
over_50.plot(kind = 'scatter', x = 'age', y = 'chol', c = 'target')

# %%
# OO (Object Oriented) method

fig, ax = plt.subplots(figsize = (10, 6))
over_50.plot(kind = 'scatter', x = 'age', y = 'chol', c = 'target', ax = ax);

# %%
## OO method mixed with pyplot

fig, ax = plt.subplots(figsize = (10, 6))
over_50.plot(kind = 'scatter', x = 'age', y = 'chol', c = 'target', ax = ax);
ax.set_xlim([45, 100]);

# %%
## OO method from Scratch

fig, ax = plt.subplots(figsize = (10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# %%
heart_disease.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
## OO method from Scratch

fig, ax = plt.subplots(figsize = (10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# %%
## OO method from Scratch

fig, ax = plt.subplots(figsize = (10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Add a legend
plt.legend(*scatter.legend_elements(), title="Target")

# ax.legend( title="Target")

# plt.show()

# %%
## OO method from Scratch

fig, ax = plt.subplots(figsize = (10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a line 

ax.axhline(over_50["chol"].mean());

# %%
## OO method from Scratch
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal -- line 

ax.axhline(over_50["chol"].mean(), linestyle="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot

fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 rows
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 8))

# Add data for ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")


# Add data for ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# ## Customizing your plots

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# plot befor changing style 

car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
plt.style.use('ggplot')
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
car_sales["Price"].plot.hist();

# %%
## create some dummy data

x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.60152783,  0.3746413 , -0.58164767, -1.61812301],
#        [-0.31412279, -0.63535925, -0.30112626, -0.50770157],
#        [-0.30034693, -1.63982013, -0.19597417,  0.43876278],
#        [-0.96061919, -0.19762424,  1.73539665, -1.68722699],
#        [-1.08154766,  0.27957872, -0.5155697 , -0.33861896],
#        [ 0.6083544 , -0.71543236, -1.65404257, -0.42941734],
#        [ 0.75383726,  1.861558  , -1.92831312, -1.36290286],
#        [-0.01886569, -0.80440879, -0.22007938,  2.17038634],
#        [ 0.73565242,  1.1979947 , -1.39328624, -1.54385658],
#        [ 0.58267181,  0.71442883, -0.53154716,  0.85842611]])

# %%
df
# Out:
#           A         B         C         D
# 0  0.469202  0.479320  0.084405  0.798743
# 1  0.743405  0.547625  0.342032  0.458665
# 2  0.451481  0.960563  0.921120  0.966265
# 3  0.742948  0.388673  0.674784  0.471614
# 4  0.300000  0.400312  0.391945  0.340220
# 5  0.419478  0.518102  0.104705  0.647788
# 6  0.111185  0.177614  0.009990  0.472714
# 7  0.139302  0.137253  0.985501  0.458811
# 8  0.066836  0.714188  0.942029  0.209919
# 9  0.066809  0.955564  0.252200  0.395744

# %%
ax = df.plot(kind = 'bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax = df.plot(kind='bar')
ax.set(title="Random Number Bar Graph from DataFrame", 
       xlabel="Row number", 
       ylabel="Random number")
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.axhline(y=over_50["chol"].mean(), 
           c='b', 
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), title="Target");

# %%
# Change cmap and horizontal line to be a different colour
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"], 
                     cmap="winter") #this changes the color scheme


ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
ax.axhline(y=over_50["chol"].mean(), 
           color='r', 
           linestyle='--', 
           label="Average");


ax.legend(*scatter.legend_elements(), title="Target");

# %%
# change the xlim and ylim

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                     )
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      )
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Set the x axis
ax0.set_xlim([50, 80])

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Set the y axis
ax1.set_ylim([60, 200])

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');
