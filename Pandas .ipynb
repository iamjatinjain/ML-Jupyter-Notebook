# %%
import pandas as pd

# %%
# 2 main datatypes 
series = pd.Series(["BMW", "Honda","Toyota"])

# %%
series
# Out:
# 0       BMW
# 1     Honda
# 2    Toyota
# dtype: object

# %%
 # series - 1 dimensional

# %%
colors = pd.Series(["Red","White","Blue"])

# %%
colors
# Out:
# 0      Red
# 1    White
# 2     Blue
# dtype: object

# %%
# DataFrame = 2 dimensional
car_data = pd.DataFrame({"car make": series, "colors": colors})
car_data
# Out:
#   car make colors
# 0      BMW    Red
# 1    Honda  White
# 2   Toyota   Blue

# %%
# Import Data
car_sales = pd.read_csv("car-data.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

#function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# Make             10 non-null object
# Colour           10 non-null object
# Odometer (KM)    10 non-null int64
# Doors            10 non-null int64
# Price            10 non-null object
# dtypes: int64(2), object(3)
# memory usage: 480.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc
animals = pd.Series(["cat", "dog", "birds", "python", "snake"])

# %%
animals
# Out:
# 0       cat
# 1       dog
# 2     birds
# 3    python
# 4     snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 'python'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'python'

# %%
car_sales.iloc[4]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Groupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].dtypes
# Out:
# dtype('O')

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales["Price"].plot()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]= car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"].fillna(5, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
# column from Python List
fuel_economy = [7.5, 3.2, 4.2, 7.6, 6.7, 8.9, 9.8, 3.5, 5.3, 4.5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             3.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 8  toyota  White          60000      4   625000    5.0             5.3
# 9  nissan  White          31600      4   970000    5.0             4.5

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             3.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 8  toyota  White          60000      4   625000    5.0             5.3
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)
# 0            11253.225
# 1             2812.768
# 2             1367.058
# 3              849.604
# 4            14277.365
# 5             8829.957
# ...

# %%
# create column from single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             3.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 8  toyota  White          60000      4   625000    5.0             5.3
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels
# 0            11253.225                 4
# 1             2812.768                 4
# 2             1367.058                 4
# ...

# %%
car_sales["Passed road saftey"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             3.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 8  toyota  White          60000      4   625000    5.0             5.3
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             2812.768                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    int64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road saftey        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             3.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 8  toyota  White          60000      4   625000    5.0             5.3
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             2812.768                 4                True
# ...

# %%
car_sales.sample(frac = 1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 1   honda    Red          87899      4   500000    5.0             3.2
# 9  nissan  White          31600      4   970000    5.0             4.5
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 0  toyota  White         150043      4   400000    5.0             7.5
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 4  nissan  White         213095      4   350000    5.0             6.7
# 8  toyota  White          60000      4   625000    5.0             5.3
# 5  toyota  Green          99213      4   450000    5.0             8.9
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 2             1367.058                 4                True
# 1             2812.768                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             3.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 8  toyota  White          60000      4   625000    5.0             5.3
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             2812.768                 4                True
# ...

# %%
car_sales_shuffles = car_sales.sample(frac = 1)

# %%
car_sales_shuffles
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 1   honda    Red          87899      4   500000    5.0             3.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 0  toyota  White         150043      4   400000    5.0             7.5
# 9  nissan  White          31600      4   970000    5.0             4.5
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 8  toyota  White          60000      4   625000    5.0             5.3
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 1             2812.768                 4                True
# 3              849.604                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             3.2
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 8  toyota  White          60000      4   625000    5.0             5.3
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             2812.768                 4                True
# ...

# %%
car_sales_shuffles
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 9  nissan  White          31600      4   970000    5.0             4.5
# 8  toyota  White          60000      4   625000    5.0             5.3
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 0  toyota  White         150043      4   400000    5.0             7.5
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
# 1   honda    Red          87899      4   500000    5.0             3.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 3              849.604                 4                True
# 6             4478.404                 4                True
# ...

# %%
#only select 20% of data
car_sales_shuffles.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 8  toyota  White          60000      4  625000    5.0             5.3
# 2  toyota   Blue          32549      3  700000    5.0             4.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 8             3180.000                 4                True
# 2             1367.058                 4                True

# %%
car_sales_shuffles.sample(frac = 0.01)
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price, Seats, Fuel per 100KM, Total fuel used (L), Number of wheels, Passed road saftey]
# Index: []

# %%
car_sales_shuffles.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      3     bmw  Black          11179      5  2200000    5.0             7.6
# 1      6   honda   Blue          45698      4   750000    5.0             9.8
# 2      2  toyota   Blue          32549      3   700000    5.0             4.2
# 3      9  nissan  White          31600      4   970000    5.0             4.5
# 4      8  toyota  White          60000      4   625000    5.0             5.3
# 5      7   honda   Blue          54738      4   700000    5.0             3.5
# 6      0  toyota  White         150043      4   400000    5.0             7.5
# 7      4  nissan  White         213095      4   350000    5.0             6.7
# 8      5  toyota  Green          99213      4   450000    5.0             8.9
# 9      1   honda    Red          87899      4   500000    5.0             3.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# ...

# %%
car_sales_shuffles.reset_index(inplace = True)

# %%
car_sales_shuffles
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 1   honda    Red          87899      4   500000    5.0             3.2
# 3     bmw  Black          11179      5  2200000    5.0             7.6
# 0  toyota  White         150043      4   400000    5.0             7.5
# 9  nissan  White          31600      4   970000    5.0             4.5
# 2  toyota   Blue          32549      3   700000    5.0             4.2
# 6   honda   Blue          45698      4   750000    5.0             9.8
# 8  toyota  White          60000      4   625000    5.0             5.3
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 4  nissan  White         213095      4   350000    5.0             6.7
# 5  toyota  Green          99213      4   450000    5.0             8.9
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 1             2812.768                 4                True
# 3              849.604                 4                True
# ...

# %%
car_sales_shuffles.reset_index(drop = True, inplace = True)

# %%
car_sales_shuffles
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0   honda    Red          87899      4   500000    5.0             3.2
# 1     bmw  Black          11179      5  2200000    5.0             7.6
# 2  toyota  White         150043      4   400000    5.0             7.5
# 3  nissan  White          31600      4   970000    5.0             4.5
# 4  toyota   Blue          32549      3   700000    5.0             4.2
# 5   honda   Blue          45698      4   750000    5.0             9.8
# 6  toyota  White          60000      4   625000    5.0             5.3
# 7   honda   Blue          54738      4   700000    5.0             3.5
# 8  nissan  White         213095      4   350000    5.0             6.7
# 9  toyota  Green          99213      4   450000    5.0             8.9
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0             2812.768                 4                True
# 1              849.604                 4                True
# ...
